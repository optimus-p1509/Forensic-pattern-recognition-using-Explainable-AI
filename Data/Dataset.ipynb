# %%
import csv
import pandas as pd
import numpy as np
import random

FifteenFeatures = pd.read_csv("15features.csv", delimiter = ',')
# FifteenFeatures = FifteenFeatures.drop('imagename', axis=1)
FifteenFeatures
# Out:
#              imagename  pen_pressure  letter_spacing  size  dimension  \
# 0       0968c_num1.png             2               2     2          1
# 1       0809c_num2.png             2               2     2          2
# 2       0237b_num6.png             2               2     2          2
# 3       0069b_num2.png             2               2     2          1
# 4       0966c_num4.png             2               2     2          2
# 5       1316a_num2.png             2               2     1          1
# 6       1503c_num2.png             2               1     2          2
# 7       0113c_num1.png             2               3     2          2
# 8       0221a_num6.png             2               2     2          2
# 9       0068a_num4.png             1               1     2          2
# 10      1094b_num1.png             2               3     1          1
# 11      0337c_num6.png             2               2     2          2
# ...

# %%
import time
columns = FifteenFeatures.columns
print(columns)
# Out:
# Index(['imagename', 'pen_pressure', 'letter_spacing', 'size', 'dimension',
#        'is_lowercase', 'is_continuous', 'slantness', 'tilt', 'entry_stroke_a',
#        'staff_of_a', 'formation_n', 'staff_of_d', 'exit_stroke_d',
#        'word_formation', 'constancy'],
#       dtype='object')

# %%
import re
cols = ['image_left','pen_pressure_left', 'is_lowercase_left', 'letter_spacing_left', 'size_left', 'slantness_left', 'staff_of_d_left', 'exit_stroke_d_left', 'entry_stroke_a_left', 'dimension_left', 'is_continuous_left', 'staff_of_a_left', 'tilt_left', 'formation_n_left', 'constancy_left', 'word_formation_left','image_right','pen_pressure_right', 'is_lowercase_right', 'letter_spacing_right', 'size_right', 'slantness_right', 'staff_of_d_right', 'exit_stroke_d_right', 'entry_stroke_a_right', 'dimension_right', 'is_continuous_right', 'staff_of_a_right', 'tilt_right', 'formation_n_right', 'constancy_right', 'word_formation_right']
# print(cols)
# rows_same = []
# rows_diff = []
# while(len(rows_diff)!=500):
#     num1 = random.randint(1,13569)
#     num2 = random.randint(1,13569)
#     if re.split(r"[a-z]", FifteenFeatures.iloc[num1][0])[0] != re.split(r"[a-z]", FifteenFeatures.iloc[num2][0])[0]:
#         row = list(FifteenFeatures.iloc[num1]) + list(FifteenFeatures.iloc[num2])
#         rows_diff.append(row)
# print(rows_diff[0])
# while(len(rows_same)!=500):
#     num1 = random.randint(1,13569)
#     num2 = random.randint(1,13569)
#     if re.split(r"[a-z]", FifteenFeatures.iloc[num1][0])[0] == re.split(r"[a-z]", FifteenFeatures.iloc[num2][0])[0]:
#         row = list(FifteenFeatures.iloc[num1]) + list(FifteenFeatures.iloc[num2])
#         rows_same.append(row)
# print(rows_same)
# finalFrame = pd.DataFrame.from_records(rows, columns=cols)
# finalFrame['h'] = 0
# cols1 = finalFrame.columns.tolist()
# cols1 = cols1[0:1] + cols1[16:17] + cols1[1:16] + cols1[17:]
# cols1
# finalFrame = finalFrame[cols2]
# # for row in finalFrame:
# import re
# # print(re.split(r"[a-z]", finalFrame['image_left'][0])[0])
# count=0
# for row in finalFrame:
#     if((re.split(r"[a-z]", finalFrame['image_left'][0])[0]) == (re.split(r"[a-z]", finalFrame['image_right'][0])[0])):
#         row['h'] = 1
#         count+=1
# print(count)

# %%
# re.split(r"[a-z]", FifteenFeatures['imagename'][0])[0]
# FifteenFeatures.loc[re.split(r"[a-z]", FifteenFeatures['imagename'])[0] == re.split(r"[a-z]", FifteenFeatures['imagename'])[0]]

# # FifteenFeatures.query(re.split(r"[a-z]", FifteenFeatures['imagename'])[0] == re.split(r"[a-z]", FifteenFeatures['imagename'][0])[0])

# %%
newCols = list(FifteenFeatures.columns)
newCols2 = []
print(newCols)
for c in newCols:
    c+="_PAIR"
    newCols2.append(c)
print(newCols2)
finalCols = newCols + newCols2
# finalCols

# finalFeatures = pd.DataFrame.from_records(, columns=finalCols)
# Out:
# ['imagename', 'pen_pressure', 'letter_spacing', 'size', 'dimension', 'is_lowercase', 'is_continuous', 'slantness', 'tilt', 'entry_stroke_a', 'staff_of_a', 'formation_n', 'staff_of_d', 'exit_stroke_d', 'word_formation', 'constancy']
# ['imagename_PAIR', 'pen_pressure_PAIR', 'letter_spacing_PAIR', 'size_PAIR', 'dimension_PAIR', 'is_lowercase_PAIR', 'is_continuous_PAIR', 'slantness_PAIR', 'tilt_PAIR', 'entry_stroke_a_PAIR', 'staff_of_a_PAIR', 'formation_n_PAIR', 'staff_of_d_PAIR', 'exit_stroke_d_PAIR', 'word_formation_PAIR', 'constancy_PAIR']

# %%
# FifteenFeatures['class'] = FifteenFeatures['imagename'][0:4]
# FifteenFeatures
# FifteenFeatures['imagename'][0][0:4]
for row in FifteenFeatures['imagename']:
    FifteenFeatures['class'] = str(row[0:4])
FifteenFeatures
# Out:
#              imagename  pen_pressure  letter_spacing  size  dimension  \
# 0       0968c_num1.png             2               2     2          1
# 1       0809c_num2.png             2               2     2          2
# 2       0237b_num6.png             2               2     2          2
# 3       0069b_num2.png             2               2     2          1
# 4       0966c_num4.png             2               2     2          2
# 5       1316a_num2.png             2               2     1          1
# 6       1503c_num2.png             2               1     2          2
# 7       0113c_num1.png             2               3     2          2
# 8       0221a_num6.png             2               2     2          2
# 9       0068a_num4.png             1               1     2          2
# 10      1094b_num1.png             2               3     1          1
# 11      0337c_num6.png             2               2     2          2
# ...

# %%
import os
from scipy.misc import imresize
import itertools
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

print(os.path.join("sqwe\qweeeeeeeq","wqee"))
pathImage = "seen-dataset\TrainingSet\0002a-num4.png"
image = plt.imread(pathImage)
plt.imshow(img)
# Out:
# sqwe\qweeeeeeeq\wqee
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-8a9d8b117fed> in <module>
#       8 print(os.path.join("sqwe\qweeeeeeeq","wqee"))
#       9 pathImage = "seen-dataset\TrainingSet\0002a-num4.png"
# ---> 10 image = plt.imread(pathImage)
#      11 plt.imshow(img)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imread(*args, **kwargs)
#    2371 @docstring.copy_dedent(_imread)
#    2372 def imread(*args, **kwargs):
# -> 2373     return _imread(*args, **kwargs)
#    2374
#    2375
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1374             return handler(fd)
#    1375         else:
# -> 1376             with open(fname, 'rb') as fd:
#    1377                 return handler(fd)
#    1378     else:
#
# ValueError: embedded null character
